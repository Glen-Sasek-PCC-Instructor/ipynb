# %% [markdown]
# # **Dogs Dataset - Crosstab Chart**

# %% [markdown]
# **IMPORTANT!!** You must run each code block from top to bottom. First, run the import block, then the "Create a dataframe" block, then the "df.columns" block, etc. The code will not execute until you run the block by clicking on the play button. To see the play button, hover over the [ ] in each block.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Download the [dogs.csv](https://drive.google.com/file/d/1JB7i-u7q3YpuxihimQG5GiGTKac-_MLj/view?usp=sharing) file onto your computer and drag into this Notebook.

# %%
# Create a dataframe from our csv file
df = pd.read_csv("dogs.csv")

# %%
df.columns
# Out:
# Index(['id', 'Name', 'Breed Group', 'Bred For', 'Min Life Span',
#        'Max Life Span', 'Min Height', 'Max Height', 'Min Weight', 'Max Weight',
#        'Temperament', 'Image URL'],
#       dtype='object')

# %% [markdown]
# Run the code below to create a cross-tabulation or crosstab chart. A crosstab chart counts how many times combinations of values appear. This chart shows the count of each Max Life Span value per Breed Group.
#
# With your partner, choose 2 columns to discover interesting information. Use mathematical terms (percents, counts, averages, ranges, etc.) and correct use of units of measurement (percents, counts, money, prediction scores, etc.)Remember to update the title and axis labels. Answer the questions below (double click on this box to edit):
#
# 1. Partner Names:
#
# 2. What is the question you are trying to answer with the two column chart?
#
# 3. Were the plot results as you expected, or unexpected?
#
# 4. What is one piece of information someone could learn from your plot?
#
# 5. What, if any, assumptions are you making when reading the plot?
#
#
# Click on the share link at the top right corner of this Notebook and change so 'anyone with the link can view'. Copy the link and post as a comment on the lesson slides.

# %% [markdown]
# # Cross-tabulation (Crosstab) Chart

# %%
# Add a title to the chart using Python print() statement
print('\tMaximum Life Span Counts per Breeding Group\n')

# Create the crosstab chart, specify two column names: index = the rows, and
# columns = the columns.
pd.crosstab(index=df['Breed Group'], columns=[df['Max Life Span']], margins=True)
# Out:
# 	Maximum Life Span Counts per Breeding Group
# Max Life Span  8  10  11  12  13  14  15  16  17  18  20  All
# Breed Group
# Herding        0   0   0   4   2   3   2   1   0   0   0   12
# Hound          1   2   0   4   3   4   3   1   0   0   0   18
# Mixed          0   0   0   0   2   0   0   0   0   0   0    2
# Non-Sporting   0   0   0   0   2   1   5   1   0   0   0    9
# Sporting       0   0   1   5   1   6   5   1   0   0   0   19
# Terrier        0   0   0   0   1   2   5   1   0   0   1   10
# Toy            0   0   0   1   0   4   3   1   1   2   0   12
# Working        1   6   1   8   2   3   2   0   0   0   0   23
# All            2   8   2  22  13  23  25   6   1   2   1  105

# %% [markdown]
# # Crosstab Chart with Heatmap
#
# Importing the Seaborn library, you can use functions to draw a heatmap, which
# darkens the cells with higher values.

# %%
# Add a title to the chart using Python print() statement
print('Maximum Life Span Counts per Breeding Group\n')

# Adding a heatmap to highlight the higher numbers, you must import
# the import seaborn libarary: import seaborn as sns
orange = sns.light_palette("orange", as_cmap=True)

# Create the crosstab chart, specify two column names: index = the rows, and
# columns = the columns.
pd.crosstab(index=df['Breed Group'], columns=[df['Max Life Span']]).style.background_gradient(cmap=orange)
# Out:
# Maximum Life Span Counts per Breeding Group
# <style type="text/css">
# #T_58c70_row0_col0, #T_58c70_row0_col1, #T_58c70_row0_col2, #T_58c70_row0_col8, #T_58c70_row0_col9, #T_58c70_row0_col10, #T_58c70_row1_col2, #T_58c70_row1_col8, #T_58c70_row1_col9, #T_58c70_row1_col10, #T_58c70_row2_col0, #T_58c70_row2_col1, #T_58c70_row2_col2, #T_58c70_row2_col3, #T_58c70_row2_col5, #T_58c70_row2_col6, #T_58c70_row2_col7, #T_58c70_row2_col8, #T_58c70_row2_col9, #T_58c70_row2_col10, #T_58c70_row3_col0, #T_58c70_row3_col1, #T_58c70_row3_col2, #T_58c70_row3_col3, #T_58c70_row3_col8, #T_58c70_row3_col9, #T_58c70_row3_col10, #T_58c70_row4_col0, #T_58c70_row4_col1, #T_58c70_row4_col8, #T_58c70_row4_col9, #T_58c70_row4_col10, #T_58c70_row5_col0, #T_58c70_row5_col1, #T_58c70_row5_col2, #T_58c70_row5_col3, #T_58c70_row5_col8, #T_58c70_row5_col9, #T_58c70_row6_col0, #T_58c70_row6_col1, #T_58c70_row6_col2, #T_58c70_row6_col4, #T_58c70_row6_col10, #T_58c70_row7_col7, #T_58c70_row7_col8, #T_58c70_row7_col9, #T_58c70_row7_col10 {
#   background-color: #f3f0ee;
#   color: #000000;
# }
# #T_58c70_row0_col3, #T_58c70_row0_col5, #T_58c70_row1_col3, #T_58c70_row7_col5 {
#   background-color: #f9ca77;
#   color: #000000;
# }
# #T_58c70_row0_col4, #T_58c70_row1_col5, #T_58c70_row2_col4, #T_58c70_row3_col4, #T_58c70_row6_col5, #T_58c70_row7_col4 {
#   background-color: #fbbe4f;
#   color: #000000;
# }
# #T_58c70_row0_col6, #T_58c70_row7_col6 {
#   background-color: #f8d28f;
#   color: #000000;
# }
# #T_58c70_row0_col7, #T_58c70_row1_col0, #T_58c70_row1_col4, #T_58c70_row1_col7, #T_58c70_row3_col6, #T_58c70_row3_col7, #T_58c70_row4_col2, #T_58c70_row4_col5, #T_58c70_row4_col6, #T_58c70_row4_col7, #T_58c70_row5_col6, #T_58c70_row5_col7, #T_58c70_row5_col10, #T_58c70_row6_col7, #T_58c70_row6_col8, #T_58c70_row6_col9, #T_58c70_row7_col0, #T_58c70_row7_col1, #T_58c70_row7_col2, #T_58c70_row7_col3 {
#   background-color: #ffa500;
#   color: #000000;
# }
# #T_58c70_row1_col1, #T_58c70_row4_col4, #T_58c70_row5_col4, #T_58c70_row5_col5 {
#   background-color: #f7d79f;
#   color: #000000;
# }
# #T_58c70_row1_col6, #T_58c70_row6_col6 {
#   background-color: #fac35f;
#   color: #000000;
# }
# #T_58c70_row3_col5 {
#   background-color: #f5e4c7;
#   color: #000000;
# }
# #T_58c70_row4_col3 {
#   background-color: #fac159;
#   color: #000000;
# }
# #T_58c70_row6_col3 {
#   background-color: #f4e7d1;
#   color: #000000;
# }
# </style>
# <table id="T_58c70">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Max Life Span</th>
#       <th id="T_58c70_level0_col0" class="col_heading level0 col0" >8</th>
#       <th id="T_58c70_level0_col1" class="col_heading level0 col1" >10</th>
#       <th id="T_58c70_level0_col2" class="col_heading level0 col2" >11</th>
#       <th id="T_58c70_level0_col3" class="col_heading level0 col3" >12</th>
#       <th id="T_58c70_level0_col4" class="col_heading level0 col4" >13</th>
#       <th id="T_58c70_level0_col5" class="col_heading level0 col5" >14</th>
#       <th id="T_58c70_level0_col6" class="col_heading level0 col6" >15</th>
#       <th id="T_58c70_level0_col7" class="col_heading level0 col7" >16</th>
#       <th id="T_58c70_level0_col8" class="col_heading level0 col8" >17</th>
#       <th id="T_58c70_level0_col9" class="col_heading level0 col9" >18</th>
#       <th id="T_58c70_level0_col10" class="col_heading level0 col10" >20</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Breed Group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58c70_level0_row0" class="row_heading level0 row0" >Herding</th>
#       <td id="T_58c70_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_58c70_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_58c70_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_58c70_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_58c70_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_58c70_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_58c70_row0_col6" class="data row0 col6" >2</td>
#       <td id="T_58c70_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_58c70_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_58c70_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_58c70_row0_col10" class="data row0 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_58c70_level0_row1" class="row_heading level0 row1" >Hound</th>
#       <td id="T_58c70_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_58c70_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_58c70_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_58c70_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_58c70_row1_col4" class="data row1 col4" >3</td>
#       <td id="T_58c70_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_58c70_row1_col6" class="data row1 col6" >3</td>
#       <td id="T_58c70_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_58c70_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_58c70_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_58c70_row1_col10" class="data row1 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_58c70_level0_row2" class="row_heading level0 row2" >Mixed</th>
#       <td id="T_58c70_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_58c70_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_58c70_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_58c70_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_58c70_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_58c70_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_58c70_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_58c70_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_58c70_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_58c70_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_58c70_row2_col10" class="data row2 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_58c70_level0_row3" class="row_heading level0 row3" >Non-Sporting</th>
#       <td id="T_58c70_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_58c70_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_58c70_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_58c70_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_58c70_row3_col4" class="data row3 col4" >2</td>
#       <td id="T_58c70_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_58c70_row3_col6" class="data row3 col6" >5</td>
#       <td id="T_58c70_row3_col7" class="data row3 col7" >1</td>
#       <td id="T_58c70_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_58c70_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_58c70_row3_col10" class="data row3 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_58c70_level0_row4" class="row_heading level0 row4" >Sporting</th>
#       <td id="T_58c70_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_58c70_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_58c70_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_58c70_row4_col3" class="data row4 col3" >5</td>
#       <td id="T_58c70_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_58c70_row4_col5" class="data row4 col5" >6</td>
#       <td id="T_58c70_row4_col6" class="data row4 col6" >5</td>
#       <td id="T_58c70_row4_col7" class="data row4 col7" >1</td>
#       <td id="T_58c70_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_58c70_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_58c70_row4_col10" class="data row4 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_58c70_level0_row5" class="row_heading level0 row5" >Terrier</th>
#       <td id="T_58c70_row5_col0" class="data row5 col0" >0</td>
#       <td id=
